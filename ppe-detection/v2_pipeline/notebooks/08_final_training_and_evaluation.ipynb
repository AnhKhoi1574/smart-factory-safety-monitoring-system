# %% [markdown]
# # 08 Final Training and Evaluation
#
# Train the final model using the chosen configuration and evaluate it once on the untouched test split.

# %%
from pathlib import Path
import sys

def find_v2_root(start: Path) -> Path:
    for candidate in (start, *start.parents):
        if candidate.name == "v2_pipeline" and (candidate / "src").exists():
            return candidate
    raise RuntimeError("Could not locate the v2_pipeline root.")

V2_ROOT = find_v2_root(Path.cwd().resolve())
PROJECT_ROOT = V2_ROOT.parent.parent
if str(V2_ROOT) not in sys.path:
    sys.path.insert(0, str(V2_ROOT))

print(f"PROJECT_ROOT={PROJECT_ROOT}")
print(f"V2_ROOT={V2_ROOT}")

# %% [markdown]
# ## TODO
#
# - Lock the final architecture and augmentation strategy.
# - Train the final model.
# - Evaluate exactly once on the untouched test set.
# - Save metrics and figures under `reports/training/`.
# - Export the final model if needed.
