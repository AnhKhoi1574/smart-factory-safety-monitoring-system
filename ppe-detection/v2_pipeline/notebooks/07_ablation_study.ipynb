# %% [markdown]
# # 07 Ablation Study
#
# Run controlled augmentation ablations after selecting the best YOLO architecture from the candidate model stage.

# %%
from pathlib import Path
import sys

def find_v2_root(start: Path) -> Path:
    for candidate in (start, *start.parents):
        if candidate.name == "v2_pipeline" and (candidate / "src").exists():
            return candidate
    raise RuntimeError("Could not locate the v2_pipeline root.")

V2_ROOT = find_v2_root(Path.cwd().resolve())
PROJECT_ROOT = V2_ROOT.parent.parent
if str(V2_ROOT) not in sys.path:
    sys.path.insert(0, str(V2_ROOT))

print(f"PROJECT_ROOT={PROJECT_ROOT}")
print(f"V2_ROOT={V2_ROOT}")

# %% [markdown]
# ## TODO
#
# - Select the best architecture from candidate training.
# - Train on `exp_A` through `exp_D`.
# - Record validation metrics for each ablation.
# - Summarize the augmentation impact before final training.
