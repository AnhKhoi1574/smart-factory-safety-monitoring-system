# %% [markdown]
# # 09 Inference Tracking Demo
#
# Run YOLO inference with ByteTrack or BoT-SORT and apply PPE association logic for downstream safety compliance reasoning.

# %%
from pathlib import Path
import sys

def find_v2_root(start: Path) -> Path:
    for candidate in (start, *start.parents):
        if candidate.name == "v2_pipeline" and (candidate / "src").exists():
            return candidate
    raise RuntimeError("Could not locate the v2_pipeline root.")

V2_ROOT = find_v2_root(Path.cwd().resolve())
PROJECT_ROOT = V2_ROOT.parent.parent
if str(V2_ROOT) not in sys.path:
    sys.path.insert(0, str(V2_ROOT))

print(f"PROJECT_ROOT={PROJECT_ROOT}")
print(f"V2_ROOT={V2_ROOT}")

# %% [markdown]
# ## TODO
#
# - Load the final detector.
# - Run tracked inference on a sample video.
# - Compare ByteTrack and BoT-SORT if needed.
# - Apply person-to-PPE association logic.
# - Visualize compliance overlays and export a demo artifact.
